# %% [markdown]
# # Parser demo
#
# Quick check that invoice HTML is parsed as expected (using the Entersoft/Sklavenitis sample).

# %%
# # Install optional dependencies if running outside the container
# !pip install fastapi uvicorn

# %%
from pathlib import Path
import json
import app

sample_path = Path("data/samples/entersoft.mhtml")
html_text = sample_path.read_text(encoding="utf-8")

invoice = app.parse_invoice(html_text)

print("Parser:", invoice.get("parser"))
print("Supplier:", invoice.get("supplier_name"))
print("Invoice number:", invoice.get("invoice_number"))
print("Invoice date:", invoice.get("invoice_date"))
print("Payment method:", invoice.get("payment_method"))
print("Total amount:", invoice.get("total_amount"))
print("Items parsed:", len(invoice.get("items", [])))
print("\nFirst 3 items:\n", json.dumps(invoice.get("items", [])[:3], ensure_ascii=False, indent=2))
# Out:
# ---- DEBUG ---- mhtml html parts found=2 using_len=42490
# ---- DEBUG ---- mhtml html parts found=2 using_len=42490
# ---- DEBUG ---- mhtml detected -> extracted html len=42490
# ---- DEBUG ---- mhtml detected -> extracted html len=42490
# Parser: entersoft
# Supplier: ΕΛΛΗΝΙΚΕΣ ΥΠΕΡΑΓΟΡΕΣ ΣΚΛΑΒΕΝΙΤΗΣ Α.Ε.Ε.
# Invoice number: 03 65983
# Invoice date: 20-12-2025
# Payment method: POS / e-POS
# Total amount: 163.15
# Items parsed: 41
#
# First 3 items:
#  [
#   {
#     "id": "3d169e6760",
#     "description": "ΞΥΛΟΚΑΡΒΟΥΝΑ 5kg SKLA5",
#     "quantity": 1.0,
#     "price": 4.86,
#     "total": 6.0,
#     "participants": []
#   },
#   {
#     "id": "3aaa4aa094",
#     "description": "ΗΛΙΕΛΑΙΟ ΜΑΡΑΤΑ 2L",
#     "quantity": 1.0,
#     "price": 3.45,
#     "total": 3.9,
#     "participants": []
#   },
#   {
#     "id": "91ccb621d5",
#     "description": "ΓΑΛΑ ΦΡΕΣΚΟ ΜΑΡΑΤΑ 3,5%ΛΙΠ.100% ΕΛΛ.1L",
#     "quantity": 1.0,
#     "price": 0.93,
#     "total": 1.05,
#     "participants": []
#   }
# ]

# %%
# Helper: parse any HTML file path and view summary
def summarize_invoice(path_str: str):
    html = Path(path_str).read_text(encoding="utf-8")
    data = app.parse_invoice(html)
    print(f"Parsed with: {data.get('parser')}")
    print(f"Supplier: {data.get('supplier_name')}")
    print(f"Items: {len(data.get('items', []))}, total: {data.get('total_amount')}")
    return data

# Example usage:
# summarize_invoice("uploads/receipt-xxxx.html")

# %% [markdown]
# ## QR debug helper
# Run the cell below with a path to your QR image. It tries local decode (Pillow/pyzbar), optionally remote API, and shows invoice parsing if HTML is found.

# %%
from pathlib import Path
import urllib.error
import app

def inspect_qr_image(path_str: str, try_remote: bool = False, fetch_if_url: bool = False):
    path = Path(path_str)
    if not path.exists():
        print(f'File not found: {path}')
        return None
    data = path.read_bytes()
    print(f'Loaded {path} ({len(data)} bytes)')
    decoded_local, local_err = app.decode_qr_locally(data)
    if decoded_local:
        print('Local decode: success')
        print('  preview:', decoded_local[:200])
    else:
        print(f'Local decode: none (err={local_err})')
    decoded_remote = None
    if try_remote:
        try:
            decoded_remote = app.post_qr_for_data(data, filename=path.name)
            print('Remote decode: success')
            print('  preview:', str(decoded_remote)[:200])
        except urllib.error.URLError as e:
            print('Remote decode URLError:', e)
        except Exception as e:
            print('Remote decode error:', e)
    qr_payload = decoded_local or decoded_remote
    html_text = None
    if isinstance(qr_payload, str) and qr_payload.startswith(('http://', 'https://')) and fetch_if_url:
        try:
            html_text = app.fetch_html(qr_payload)
            print(f'Fetched HTML from QR URL (len={len(html_text)})')
        except urllib.error.URLError as e:
            print('Fetch HTML URLError:', e)
    elif isinstance(qr_payload, str):
        html_text = qr_payload
    if html_text:
        parsed = app.parse_invoice(html_text)
        print('Parsed invoice summary:')
        print('  parser:', parsed.get('parser'))
        print('  supplier:', parsed.get('supplier_name'))
        print('  items:', len(parsed.get('items', [])), 'total:', parsed.get('total_amount'))
        return parsed
    return {'local': decoded_local, 'remote': decoded_remote, 'local_err': local_err}

# Example: inspect_qr_image('path/to/receipt.jpg', try_remote=False, fetch_if_url=False)

# %%
import importlib, app
importlib.reload(app)
# Out:
# <module 'app' from '/root/project-application-invoice-splitter/app.py'>

# %%
inspect_qr_image('./data/samples/entersoft.jpg', try_remote=False, fetch_if_url=True)
# Out:
# Loaded data/samples/entersoft.jpg (121179 bytes)
# ---- DEBUG ---- qr decode local: success variant=thresh size=(716, 669) symbols=1 payload_len=94
# ---- DEBUG ---- qr decode local: success variant=thresh size=(716, 669) symbols=1 payload_len=94
# Local decode: success
#   preview: https://e-invoicing.gr/edocuments/ViewInvoice/-1/b1655ed3-5453-4b5a-a3db-be01d5fd50e2_6ee4ik98
# ---- DEBUG ---- fetch_html basic len=3037
# ---- DEBUG ---- fetch_html basic len=3037
# ---- DEBUG ---- fetch_html basic len=46990
# ---- DEBUG ---- fetch_html basic len=46990
# ---- DEBUG ---- fetch_html entersoft iframe resolved url=https://e-invoicing.gr/api/GetInvoice?contentType=PEPPOL&hashToken=6ee4ik98&intRefDocID=b1655ed3-5453-4b5a-a3db-be01d5fd50e2&isPreview=True&ofenm=-1 len=46990
# ---- DEBUG ---- fetch_html entersoft iframe resolved url=https://e-invoicing.gr/api/GetInvoice?contentType=PEPPOL&hashToken=6ee4ik98&intRefDocID=b1655ed3-5453-4b5a-a3db-be01d5fd50e2&isPreview=True&ofenm=-1 len=46990
# Fetched HTML from QR URL (len=46990)
# Parsed invoice summary:
#   parser: entersoft
#   supplier: ΕΛΛΗΝΙΚΕΣ ΥΠΕΡΑΓΟΡΕΣ ΣΚΛΑΒΕΝΙΤΗΣ Α.Ε.Ε.
#   items: 41 total: 163.15
# {'supplier_name': 'ΕΛΛΗΝΙΚΕΣ ΥΠΕΡΑΓΟΡΕΣ ΣΚΛΑΒΕΝΙΤΗΣ Α.Ε.Ε.',
#  'supplier_vat': '800764388',
#  'invoice_number': '03 65983',
#  'invoice_date': '20-12-2025',
#  'currency': 'EUR',
#  'total_amount': 163.15,
#  'payment_method': 'POS / e-POS',
#  'items': [{'id': '079dfb414c',
#    'description': 'ΞΥΛΟΚΑΡΒΟΥΝΑ 5kg SKLA5',
#    'quantity': 1.0,
#    'price': 4.86,
#    'total': 6.0,
#    'participants': []},
#   {'id': 'aa7942f617',
#    'description': 'ΗΛΙΕΛΑΙΟ ΜΑΡΑΤΑ 2L',
#    'quantity': 1.0,
#    'price': 3.45,
#    'total': 3.9,
#    'participants': []},
#   {'id': '274c015b55',
#    'description': 'ΓΑΛΑ ΦΡΕΣΚΟ ΜΑΡΑΤΑ 3,5%ΛΙΠ.100% ΕΛΛ.1L',
#    'quantity': 1.0,
#    'price': 0.93,
#    'total': 1.05,
#    'participants': []},
#   {'id': 'f71626bb81',
#    'description': 'ΓΑΛΑ ΦΡΕΣΚΟ ΜΑΡΑΤΑ 3,5%ΛΙΠ.100% ΕΛΛ.1L',
#    'quantity': 1.0,
#    'price': 0.93,
#    'total': 1.05,
#    'participants': []},
#   {'id': 'c22032fee5',
#    'description': 'ΡΕΓΓΕΣ ΚΑΠΝΙΣΤΕΣ ΚΑΡΑΓΚΟΥΝΗ FAO27..',
#    'quantity': 0.322,
#    'price': 7.85714,
#    'total': 2.86,
#    'participants': []},
#   {'id': 'b84666974f',
#    'description': 'ΜΠΕΣΑΜΕΛ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 162G',
#    'quantity': 1.0,
#    'price': 1.52212,
#    'total': 1.29,
#    'participants': []},
#   {'id': '5739c31fa2',
#    'description': 'ΠΑΣΤΟΥΡΜΑΣ ΜΟΣΧΑΡΙΣΙΟΣ ΜΙΡΑΝ ΕΛΛΑΔΑΣ.',
#    'quantity': 0.268,
#    'price': 39.40299,
#    'total': 11.93,
#    'participants': []},
#   {'id': '80a784a83e',
#    'description': 'ΣΑΛΑΜΙ ΠΕΠΕΡΟΝΕ ΘΡΑΚΗΣ ΓΕΥΣ.ΦΕΤ.ΣΥΣΚ Ε/Ζ',
#    'quantity': 0.18,
#    'price': 4.77876,
#    'total': 0.82,
#    'participants': []},
#   {'id': '47f7159657',
#    'description': 'ΜΠΕΙΚΟΝ ΥΦΑΝΤΗΣ ΚΑΠΝΙΣΤΟ Α/Δ ΕΛΛΑΔΑΣ.',
#    'quantity': 0.358,
#    'price': 13.93855,
#    'total': 5.64,
#    'participants': []},
#   {'id': '72d7061772',
#    'description': 'ΣΝΙΤΣΕΛ ΚΟΤΟΠΟΥΛΟ ΠΑΝΕ ΠΡΟΨΗΜΕΝΟ ΧΥΜΑ',
#    'quantity': 1.534,
#    'price': 9.55671,
#    'total': 16.57,
#    'participants': []},
#   {'id': 'ef55437206',
#    'description': 'ΕΛΙΑ ΝΕΑΡ ΜΟΣΧ ΔΑΝΙΑΣ Α/Ο ΝΩΠΗ',
#    'quantity': 1.504,
#    'price': 14.96011,
#    'total': 25.42,
#    'participants': []},
#   {'id': 'c8bad08590',
#    'description': 'ΓΑΛΑ PIESTO ΣΥΜΠΥΚΝΩΜΕΝ.ΕΛΑΦΡΥ ΓΕΡΜ.410G',
#    'quantity': 1.0,
#    'price': 0.76,
#    'total': 0.86,
#    'participants': []},
#   {'id': '49a8d5f82d',
#    'description': 'ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G',
#    'quantity': 1.0,
#    'price': 0.44,
#    'total': 0.55,
#    'participants': []},
#   {'id': 'ace6808904',
#    'description': 'ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G',
#    'quantity': 1.0,
#    'price': 0.44,
#    'total': 0.55,
#    'participants': []},
#   {'id': 'e4593cb15a',
#    'description': 'ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G',
#    'quantity': 1.0,
#    'price': 0.44,
#    'total': 0.55,
#    'participants': []},
#   {'id': '0360cfee3d',
#    'description': 'ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G',
#    'quantity': 1.0,
#    'price': 0.44,
#    'total': 0.55,
#    'participants': []},
#   {'id': '206e783354',
#    'description': 'ΠΙΠΕΡΟΜΥΛΟΣ ΠΛΑΣΤΙΚΟ 17,5CM 4 ΧΡΩΜΑΤΑ',
#    'quantity': 1.0,
#    'price': 3.3871,
#    'total': 3.7,
#    'participants': []},
#   {'id': '50d786ad40',
#    'description': 'ΑΓΓΟΥΡΑΚΙΑ ΑΝΘΟΣ ΓΛΥΚΟΞΙΝΑ ΕΙΣΑΓΩΓΗΣ.',
#    'quantity': 2.34,
#    'price': 3.80342,
#    'total': 10.06,
#    'participants': []},
#   {'id': '98357d37f4',
#    'description': 'ΕΛΙΕΣ ΚΑΛΑΜΩΝ ΡΟΔΕΛΕΣ ΕΛΛΑΔΑΣ',
#    'quantity': 0.238,
#    'price': 5.29412,
#    'total': 1.42,
#    'participants': []},
#   {'id': 'ba271c15b7',
#    'description': 'MAΡATA ΠΕΝΕΣ ΡΙΓΕ 500G',
#    'quantity': 1.0,
#    'price': 0.55,
#    'total': 0.62,
#    'participants': []},
#   {'id': 'be8b365661',
#    'description': 'ΜΑΓΙΑ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 3Χ8G',
#    'quantity': 1.0,
#    'price': 0.86726,
#    'total': 0.68,
#    'participants': []},
#   {'id': '1f3b9ba6e7',
#    'description': 'ΤΟΜΑΤΟΠΟΛΤΟΣ ΚΥΚΝΟΣ 28% ΜΕΤ.70G',
#    'quantity': 1.0,
#    'price': 0.58,
#    'total': 0.65,
#    'participants': []},
#   {'id': '375026fd8f',
#    'description': 'ΠΑΣΣΑΤΑ PUMMARO ΚΛΑΣ.ΕΛ.ΣΥΜΠ.3Χ250G',
#    'quantity': 1.0,
#    'price': 1.85841,
#    'total': 1.36,
#    'participants': []},
#   {'id': '5e3722ae06',
#    'description': 'MAΡATA ΠΕΝΕΣ ΡΙΓΕ 500G',
#    'quantity': 1.0,
#    'price': 0.55,
#    'total': 0.62,
#    'participants': []},
#   {'id': 'f9c4a3dbd9',
#    'description': 'ΑΥΓΑ ΤΣΑΟΥΣΗ Μ-ΜΕΣΑΙΑ 30Τ',
#    'quantity': 1.0,
#    'price': 5.77,
#    'total': 6.52,
#    'participants': []},
#   {'id': 'cfc08cc40e',
#    'description': 'ΤΟΜΑΤΕΣ ΚΥΚΝΟΣ ΤΡΙΜΜΕΝΕΣ 3Χ250G',
#    'quantity': 1.0,
#    'price': 2.15929,
#    'total': 1.45,
#    'participants': []},
#   {'id': '3d8a169213',
#    'description': 'ΕΛΙΕΣ ΚΑΛΑΜΩΝ ΧΟΝΔΡΕΣ 141/160 ΕΛΛΑΔΑΣ.',
#    'quantity': 0.358,
#    'price': 5.44693,
#    'total': 2.2,
#    'participants': []},
#   {'id': '63c66badd0',
#    'description': 'ΜΕΙΓΜΑ ΠΙΠΕΡΙΩΝ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G',
#    'quantity': 1.0,
#    'price': 1.45,
#    'total': 1.64,
#    'participants': []},
#   {'id': '40098bd6bc',
#    'description': 'ΛΑΖΑΝΙΑ MELISSA 500G',
#    'quantity': 1.0,
#    'price': 2.40708,
#    'total': 1.95,
#    'participants': []},
#   {'id': 'fc6b0f6189',
#    'description': 'ΜΠΕΣΑΜΕΛ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 162G',
#    'quantity': 1.0,
#    'price': 1.52212,
#    'total': 1.29,
#    'participants': []},
#   {'id': '21ce1d0c42',
#    'description': 'ΛΑΖΑΝΙΑ MELISSA 500G',
#    'quantity': 1.0,
#    'price': 2.40708,
#    'total': 1.95,
#    'participants': []},
#   {'id': '88f9d08d6c',
#    'description': 'ΑΛΑΤΙ ΗΡΑ ΡΙΖΑΤΟ 1KG',
#    'quantity': 1.0,
#    'price': 2.0,
#    'total': 2.26,
#    'participants': []},
#   {'id': '53e8173793',
#    'description': 'ΜΕΛΙ BONAPI ΑΝΘΕΩΝ ΒΑΖΟ 500ΓΡ.',
#    'quantity': 1.0,
#    'price': 2.65487,
#    'total': 2.75,
#    'participants': []},
#   {'id': 'e64657be2d',
#    'description': 'ΚΑΦΕΣ BONORA ΦΙΛΤΡΟΥ ΦΟΥΝΤΟΥΚΙ 250G',
#    'quantity': 1.0,
#    'price': 3.76,
#    'total': 4.25,
#    'participants': []},
#   {'id': 'a950d79b38',
#    'description': 'ΚΑΦΕΣ BONORA ΦΙΛΤΡΟΥ ΒΑΝΙΛ-ΚΑΡΑΜΕΛΑ 250G',
#    'quantity': 1.0,
#    'price': 3.76,
#    'total': 4.25,
#    'participants': []},
#   {'id': 'c79e1c5256',
#    'description': 'ΖΑΧΑΡΗ ΛΕΥΚΗ ΚΡΥΣΤΑΛΛ.CRISTAL 1KG Ε.Ε',
#    'quantity': 1.0,
#    'price': 0.63,
#    'total': 0.71,
#    'participants': []},
#   {'id': '288ff020dc',
#    'description': 'ΜΕΡΕΝΤΑ ΜΕ ΦΟΥΝΤΟΥΚΙ 570G',
#    'quantity': 1.0,
#    'price': 4.57522,
#    'total': 3.41,
#    'participants': []},
#   {'id': '11a9e58621',
#    'description': 'ΑΛΕΥΡΙ ΑΓ.ΓΕΩΡΓΙΟΥ ΓΟΧ ΟΙΚΟΓ.ΣΥΣΚ.3Χ1KG',
#    'quantity': 1.0,
#    'price': 3.68142,
#    'total': 2.58,
#    'participants': []},
#   {'id': '87ecd8f12f',
#    'description': 'ΝΤΟΛΜΑΔΑΚΙΑ ΖΑΝΑΕ 370G',
#    'quantity': 7.0,
#    'price': 3.39714,
#    'total': 26.88,
#    'participants': []},
#   {'id': '0767fbc158',
#    'description': 'ΣΑΚΟΥΛΑ ΠΕΛΑΤΩΝ ΕΠΑΝΑΧΡ.ΠΕΡ.ΤΕΛ.ΜΕΓΑΛΗ',
#    'quantity': 2.0,
#    'price': 0.09,
#    'total': 0.19,
#    'participants': []},
#   {'id': 'e6d3d8bd86',
#    'description': 'Περιβαλλοντικό Τέλος&amp;Πλασ.σακ.',
#    'quantity': 2.0,
#    'price': 0.09,
#    'total': 0.17,
#    'participants': []}],
#  'parser': 'entersoft'}

# %%
html = app.fetch_html("https://e-invoicing.gr/edocuments/ViewInvoice/-1/b1655ed3-5453-4b5a-a3db-be01d5fd50e2_6ee4ik98")
print(html)
# Out:
# ---- DEBUG ---- fetch_html basic len=3037
# ---- DEBUG ---- fetch_html basic len=3037
# ---- DEBUG ---- fetch_html basic len=46990
# ---- DEBUG ---- fetch_html basic len=46990
# ---- DEBUG ---- fetch_html entersoft iframe resolved url=https://e-invoicing.gr/api/GetInvoice?contentType=PEPPOL&hashToken=6ee4ik98&intRefDocID=b1655ed3-5453-4b5a-a3db-be01d5fd50e2&isPreview=True&ofenm=-1 len=46990
# ---- DEBUG ---- fetch_html entersoft iframe resolved url=https://e-invoicing.gr/api/GetInvoice?contentType=PEPPOL&hashToken=6ee4ik98&intRefDocID=b1655ed3-5453-4b5a-a3db-be01d5fd50e2&isPreview=True&ofenm=-1 len=46990
# <!DOCTYPE html><html>
#   <head>
#     <META http-equiv="Content-Type" content="text/html; charset=utf-16">
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1"><script src="https://kendo.cdn.telerik.com/2022.2.510/js/jquery.min.js"></script><link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.0.0/dist/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
#     <style>
#           .cf th, .cf tr, .cf td{
#           border:0!important;
#           }
#
#
#           @media print {
#           .printingButton {
#           display: none;
#           }
#
#           .backgrey{
#           background-color:white
#           }
#
#           .fontSize12pt{font-size: 18px!important;}
#           .fontSize8pt{font-size: 13px!important;}
#           .fonSize10pt{font-size: 15px!important;}
#           .fontSize6pt{font-size: 12px!important;}
#           }
#
#           @media only screen and (max-width: 767px) {
#           /* Force table to not be like tables anymore */
#           #no-more-tables table,
#           #no-more-tables thead,
#           #no-more-tables tbody,
#           #no-more-tables th,
#           #no-more-tables td,
#           #no-more-tables tr {
#           display: block;
#           }
#
#
#
#           /* Hide table headers (but not display: none;, for accessibility) */
#           #no-more-tables thead tr {
#           position: absolute;
#           top: -9999px;
#           left: -9999px;
#           }
#
#
#           #no-more-tables td {
#           /* Behave like a "row" */
#           border: none;
#
#           position: relative;
#           padding-left: 50%;
#           white-space: normal;
#           text-align:right;
#           }
#
#           #no-more-tables td:before {
#           /* Now like a table header */
#           position: absolute;
#           /* Top/left values mimic padding */
#           top: 6px;
#           left: 6px;
#           width: 45%;
#           padding-right: 10px;
#           white-space: nowrap;
#           text-align:left;
#
#           }
#
#           /*
#           Label the data
#           */
#           #no-more-tables td:before { content: attr(data-title); }
#           #no-more-tables tr { border-top: 1px solid #ccc!important; }
#           #no-more-tables tr.comments{ border-top: 0px!important; }
#           #no-more-tables tr.comments td:before{ content: null!important; }
#           #no-more-tables tr.comments td{padding-left: 5px!important;text-align:left;}
#           #no-more-tables table{border-bottom: 1px solid #ccc!important;}
#
#           #signclass {
#           max-width:none!important;
#           }
#           }
#
#
#
#
#
#           tr.comments td{
#           color:#999;
#           background-color:#fff!important;
#           padding-top:0px;
#           padding-bottom:7px;
#           }
#
#           .row::after {
#           content: "";
#           clear: both;
#           display: table;
#           }
#
#           .BoldBlueHeader{
#           font-weight:bold; color:#006bc2
#           }
#
#           .fontSize12pt{font-size: 16px;}
#           .fontSize8pt{font-size: 11px;}
#           .fonSize10pt{font-size: 13px;}
#           .fontSize6pt{font-size: 10px;}
#
#           .wrap {
#           white-space: normal;
#
#           word-wrap: break-word;
#           overflow-wrap: break-word;
#           }
#
#           .row-flex {
#           display: flex;
#           flex-wrap: wrap;
#           }
#
#           .watermark {
#           color: Maroon;
#           top: 20px;
#           right: 0px;
#           font-size:22px;
#           text-align:center;
#           border:2px solid Maroon;
#           font-weight:bold;
#           }
#           .watermark .sub{
#           font-size:16px!important;
#           font-weight:normal;
#           }
#
#           .page-wrapper-shaddow {
#           box-shadow: 0 1px 1px 0 rgb(0 0 0 / 20%), 0 0.5px 20px 0 rgb(0 0 0 / 19%);
#           }
#
#           .gray-bg, .bg-muted {
#           background-color: #fff;
#           }
#
#           .buttonPrint{
#           font-size: 0.7rem;
#           padding: .1rem .75rem;
#           }
#
#         </style>
#   </head>
#   <body>
#     <div class="container  mt-3" style="font-family: Segoe UI;">
#       <div class="row">
#         <div class="col-sm-8 col-md-10">
#           <div class="row">
#             <div id="divLogo" class="col-sm-2"><img src="/CustomerLogo/logo_800764388.png" style="width:100%;max-width:100px;" alt="ΕΛΛΗΝΙΚΕΣ ΥΠΕΡΑΓΟΡΕΣ ΣΚΛΑΒΕΝΙΤΗΣ Α.Ε.Ε." onerror="document.getElementById('divLogo').style.display='none'"></div>
#             <div class="col-sm-10">
#               <div class="BoldBlueHeader fontSize12pt">ΕΛΛΗΝΙΚΕΣ ΥΠΕΡΑΓΟΡΕΣ ΣΚΛΑΒΕΝΙΤΗΣ Α.Ε.Ε.</div>
#               <div class="fontSize8pt"></div>
#               <div class="fontSize8pt"></div>
#               <div class="fontSize8pt">Λεωφ. Κηφισίας 41-43, 151 23, Μαρούσι</div>
#               <div class="fontSize8pt">Α.Φ.Μ: 800764388, Τηλ: Κέντρο: 214 100 9999 - Fax: 214 100 9998, Αρ. ΓΕΜΗ: 140091201000 - Αριθμός ΕΜΠΑ: 5877</div>
#               <div class="fontSize8pt">Email: info@sklavenitis.gr</div>
#               <div class="fontSize8pt"></div>
#             </div>
#           </div>
#           <div class="mb-3"></div>
#           <div class="BoldBlueHeader fonSize10pt">ΑΠΟΔΕΙΞΗ ΛΙΑΝΙΚΗΣ ΠΩΛΗΣΗΣ</div>
#           <div class="fontSize8pt">Αρ. Παραστατικού: 03 65983</div>
#           <div class="fontSize8pt">Ημ/νία έκδοσης: 20-12-2025</div>
#         </div>
#         <div class="col-sm-4 col-md-2"><img src="/api/CreateBarcode?barcode=https://e-invoicing.gr/edocuments/ViewInvoice/-1/b1655ed3-5453-4b5a-a3db-be01d5fd50e2_6ee4ik98" width="100" height="100" class="rounded float-right"></div>
#       </div>
#       <div class="mb-3"></div>
#       <div class="row row-flex">
#         <div class="col-md-6 pr-md-0 mb-3 " style=" display: table;">
#           <div style="padding:2px 5px;background-color:#f2f2f2;display: table-cell;" class="backgrey">
#             <div class="row BoldBlueHeader fontSize8pt">
#               <div class="col">ΣΤΟΙΧΕΙΑ ΠΕΛΑΤΗ</div>
#             </div>
#             <div class="row">
#               <div class="col fontSize8pt">
#                     Επωνυμία:
#                   </div>
#               <div class="col-8 fontSize8pt">
# 							  ΠΕΛΑΤΗΣ ΛΙΑΝΙΚΗΣ
# 						  </div>
#             </div>
#           </div>
#         </div>
#         <div class="col-md-6 pl-md-0 mb-3 " style=" display: table;">
#           <div style="padding:2px 5px;background-color:#f2f2f2;display: table-cell;" class="backgrey">
#             <div class="row BoldBlueHeader fontSize8pt">
#               <div class="col">ΣΤΟΙΧΕΙΑ ΔΙΑΚΙΝΗΣΗΣ</div>
#             </div>
#             <div class="row">
#               <div class="col fontSize8pt">
#                       Τρόπος πληρωμής:
#                   </div>
#               <div class="col-md-7 col-8 col-lg-8 fontSize8pt">
#                             POS / e-POS
#                           </div>
#             </div>
#           </div>
#         </div>
#       </div>
#       <div class="row">
#         <div class="col">
#           <div id="no-more-tables" class="table-responsive">
#             <table class="table table-sm table-hover table-condensed cf fontSize6pt">
#               <thead class="cf">
#                 <tr>
#                   <th>
#                             ΚΩΔΙΚΟΣ
#                           </th>
#                   <th>
#                             ΠΕΡΙΓΡΑΦΗ
#                           </th>
#                   <th>
#                             ΜΜ
#                           </th>
#                   <th class="text-right">
#                             ΠΟΣΟΤΗΤΑ
#                           </th>
#                   <th class="text-right">
#                             ΤΙΜΗ ΜΟΝ.
#                           </th>
#                   <th class="text-right">
#                             ΑΞΙΑ ΠΡΟ ΕΚΠΤ.
#                           </th>
#                   <th class="text-right">
#                             ΕΚΠΤ.
#                           </th>
#                   <th class="text-right">
#                             ΦΠΑ%
#                           </th>
#                   <th class="text-right">
#                             ΣΥΝΟΛΙΚΗ ΑΞΙΑ
#                           </th>
#                 </tr>
#               </thead>
#               <tbody>
#                 <tr>
#                   <td data-title="Κωδικός">1806824</td>
#                   <td data-title="Περιγραφή">ΞΥΛΟΚΑΡΒΟΥΝΑ 5kg SKLA5</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">4,86</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">6,00</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">6,00</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1066877</td>
#                   <td data-title="Περιγραφή">ΗΛΙΕΛΑΙΟ ΜΑΡΑΤΑ 2L</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,45</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">3,90</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">3,90</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1849964</td>
#                   <td data-title="Περιγραφή">ΓΑΛΑ ΦΡΕΣΚΟ ΜΑΡΑΤΑ 3,5%ΛΙΠ.100% ΕΛΛ.1L</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,93</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,05</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,05</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1849964</td>
#                   <td data-title="Περιγραφή">ΓΑΛΑ ΦΡΕΣΚΟ ΜΑΡΑΤΑ 3,5%ΛΙΠ.100% ΕΛΛ.1L</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,93</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,05</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,05</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1230959</td>
#                   <td data-title="Περιγραφή">ΡΕΓΓΕΣ ΚΑΠΝΙΣΤΕΣ ΚΑΡΑΓΚΟΥΝΗ FAO27..</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,322
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">7,85714</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,86</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">2,86</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1022024</td>
#                   <td data-title="Περιγραφή">ΜΠΕΣΑΜΕΛ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 162G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">1,52212</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,72</td>
#                   <td data-title="Έκπτωση" class="text-right">0,43</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,29</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1196736</td>
#                   <td data-title="Περιγραφή">ΠΑΣΤΟΥΡΜΑΣ ΜΟΣΧΑΡΙΣΙΟΣ ΜΙΡΑΝ ΕΛΛΑΔΑΣ.</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,268
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">39,40299</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">11,93</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">11,93</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1862171</td>
#                   <td data-title="Περιγραφή">ΣΑΛΑΜΙ ΠΕΠΕΡΟΝΕ ΘΡΑΚΗΣ ΓΕΥΣ.ΦΕΤ.ΣΥΣΚ Ε/Ζ</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,18
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">4,77876</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,97</td>
#                   <td data-title="Έκπτωση" class="text-right">0,15</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,82</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1229242</td>
#                   <td data-title="Περιγραφή">ΜΠΕΙΚΟΝ ΥΦΑΝΤΗΣ ΚΑΠΝΙΣΤΟ Α/Δ ΕΛΛΑΔΑΣ.</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,358
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">13,93855</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">5,64</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">5,64</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1073927</td>
#                   <td data-title="Περιγραφή">ΣΝΙΤΣΕΛ ΚΟΤΟΠΟΥΛΟ ΠΑΝΕ ΠΡΟΨΗΜΕΝΟ ΧΥΜΑ</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">1,534
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">9,55671</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">16,57</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">16,57</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1613574</td>
#                   <td data-title="Περιγραφή">ΕΛΙΑ ΝΕΑΡ ΜΟΣΧ ΔΑΝΙΑΣ Α/Ο ΝΩΠΗ</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">1,504
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">14,96011</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">25,42</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">25,42</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1067051</td>
#                   <td data-title="Περιγραφή">ΓΑΛΑ PIESTO ΣΥΜΠΥΚΝΩΜΕΝ.ΕΛΑΦΡΥ ΓΕΡΜ.410G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,76</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,86</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,86</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068271</td>
#                   <td data-title="Περιγραφή">ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,44</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,55</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,55</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068271</td>
#                   <td data-title="Περιγραφή">ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,44</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,55</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,55</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068271</td>
#                   <td data-title="Περιγραφή">ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,44</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,55</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,55</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068271</td>
#                   <td data-title="Περιγραφή">ΞΙΝΟ ΚΙΤΡ.ΟΞΥ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,44</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,55</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,55</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1924391</td>
#                   <td data-title="Περιγραφή">ΠΙΠΕΡΟΜΥΛΟΣ ΠΛΑΣΤΙΚΟ 17,5CM 4 ΧΡΩΜΑΤΑ</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,3871</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">4,20</td>
#                   <td data-title="Έκπτωση" class="text-right">0,50</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">3,70</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1207374</td>
#                   <td data-title="Περιγραφή">ΑΓΓΟΥΡΑΚΙΑ ΑΝΘΟΣ ΓΛΥΚΟΞΙΝΑ ΕΙΣΑΓΩΓΗΣ.</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">2,34
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,80342</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">10,06</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">10,06</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1260580</td>
#                   <td data-title="Περιγραφή">ΕΛΙΕΣ ΚΑΛΑΜΩΝ ΡΟΔΕΛΕΣ ΕΛΛΑΔΑΣ</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,238
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">5,29412</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,42</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,42</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1067028</td>
#                   <td data-title="Περιγραφή">MAΡATA ΠΕΝΕΣ ΡΙΓΕ 500G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,55</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,62</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,62</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1230652</td>
#                   <td data-title="Περιγραφή">ΜΑΓΙΑ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 3Χ8G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,86726</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,98</td>
#                   <td data-title="Έκπτωση" class="text-right">0,30</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,68</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1228418</td>
#                   <td data-title="Περιγραφή">ΤΟΜΑΤΟΠΟΛΤΟΣ ΚΥΚΝΟΣ 28% ΜΕΤ.70G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,58</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,65</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,65</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1257722</td>
#                   <td data-title="Περιγραφή">ΠΑΣΣΑΤΑ PUMMARO ΚΛΑΣ.ΕΛ.ΣΥΜΠ.3Χ250G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">1,85841</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,10</td>
#                   <td data-title="Έκπτωση" class="text-right">0,74</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,36</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1067028</td>
#                   <td data-title="Περιγραφή">MAΡATA ΠΕΝΕΣ ΡΙΓΕ 500G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,55</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,62</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,62</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068706</td>
#                   <td data-title="Περιγραφή">ΑΥΓΑ ΤΣΑΟΥΣΗ Μ-ΜΕΣΑΙΑ 30Τ</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">5,77</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">6,52</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">6,52</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1856681</td>
#                   <td data-title="Περιγραφή">ΤΟΜΑΤΕΣ ΚΥΚΝΟΣ ΤΡΙΜΜΕΝΕΣ 3Χ250G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">2,15929</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,44</td>
#                   <td data-title="Έκπτωση" class="text-right">0,99</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,45</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1067103</td>
#                   <td data-title="Περιγραφή">ΕΛΙΕΣ ΚΑΛΑΜΩΝ ΧΟΝΔΡΕΣ 141/160 ΕΛΛΑΔΑΣ.</td>
#                   <td data-title="Μ.Μ.">Κιλό</td>
#                   <td class="text-right" data-title="Ποσότητα">0,358
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">5,44693</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,20</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">2,20</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1068264</td>
#                   <td data-title="Περιγραφή">ΜΕΙΓΜΑ ΠΙΠΕΡΙΩΝ ΣΚΛΑΒΕΝΙΤΗΣ ΕΙΣ.50G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">1,45</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,64</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,64</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1899579</td>
#                   <td data-title="Περιγραφή">ΛΑΖΑΝΙΑ MELISSA 500G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">2,40708</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,72</td>
#                   <td data-title="Έκπτωση" class="text-right">0,77</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,95</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1022024</td>
#                   <td data-title="Περιγραφή">ΜΠΕΣΑΜΕΛ ΓΙΩΤΗΣ ΣΤΙΓΜΗΣ 162G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">1,52212</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">1,72</td>
#                   <td data-title="Έκπτωση" class="text-right">0,43</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,29</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1899579</td>
#                   <td data-title="Περιγραφή">ΛΑΖΑΝΙΑ MELISSA 500G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">2,40708</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,72</td>
#                   <td data-title="Έκπτωση" class="text-right">0,77</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">1,95</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1222932</td>
#                   <td data-title="Περιγραφή">ΑΛΑΤΙ ΗΡΑ ΡΙΖΑΤΟ 1KG</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">2,00</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">2,26</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">2,26</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1196338</td>
#                   <td data-title="Περιγραφή">ΜΕΛΙ BONAPI ΑΝΘΕΩΝ ΒΑΖΟ 500ΓΡ.</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">2,65487</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">3,00</td>
#                   <td data-title="Έκπτωση" class="text-right">0,25</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">2,75</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1066733</td>
#                   <td data-title="Περιγραφή">ΚΑΦΕΣ BONORA ΦΙΛΤΡΟΥ ΦΟΥΝΤΟΥΚΙ 250G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,76</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">4,25</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">4,25</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1066739</td>
#                   <td data-title="Περιγραφή">ΚΑΦΕΣ BONORA ΦΙΛΤΡΟΥ ΒΑΝΙΛ-ΚΑΡΑΜΕΛΑ 250G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,76</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">4,25</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">4,25</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1064360</td>
#                   <td data-title="Περιγραφή">ΖΑΧΑΡΗ ΛΕΥΚΗ ΚΡΥΣΤΑΛΛ.CRISTAL 1KG Ε.Ε</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,63</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,71</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,71</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1040059</td>
#                   <td data-title="Περιγραφή">ΜΕΡΕΝΤΑ ΜΕ ΦΟΥΝΤΟΥΚΙ 570G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">4,57522</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">5,17</td>
#                   <td data-title="Έκπτωση" class="text-right">1,76</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">3,41</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1914758</td>
#                   <td data-title="Περιγραφή">ΑΛΕΥΡΙ ΑΓ.ΓΕΩΡΓΙΟΥ ΓΟΧ ΟΙΚΟΓ.ΣΥΣΚ.3Χ1KG</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">1,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,68142</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">4,16</td>
#                   <td data-title="Έκπτωση" class="text-right">1,58</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">2,58</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1223496</td>
#                   <td data-title="Περιγραφή">ΝΤΟΛΜΑΔΑΚΙΑ ΖΑΝΑΕ 370G</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">7,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">3,39714</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">26,88</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">13%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">26,88</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">1158807</td>
#                   <td data-title="Περιγραφή">ΣΑΚΟΥΛΑ ΠΕΛΑΤΩΝ ΕΠΑΝΑΧΡ.ΠΕΡ.ΤΕΛ.ΜΕΓΑΛΗ</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">2,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,09</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,19</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,19</td>
#                 </tr>
#                 <tr>
#                   <td data-title="Κωδικός">PERTEL</td>
#                   <td data-title="Περιγραφή">Περιβαλλοντικό Τέλος&amp;Πλασ.σακ.</td>
#                   <td data-title="Μ.Μ.">Τεμάχιο</td>
#                   <td class="text-right" data-title="Ποσότητα">2,00
#                               </td>
#                   <td data-title="Τιμή μονάδας" class="text-right">0,09</td>
#                   <td data-title="Αξία προ έκπτωσης" class="text-right">0,17</td>
#                   <td data-title="Έκπτωση" class="text-right">0,00</td>
#                   <td class="text-right" data-title="ΦΠΑ%">24%
#                               </td>
#                   <td data-title="Συνολική Αξία" class="text-right">0,17</td>
#                 </tr>
#               </tbody>
#             </table>
#           </div>
#           <div class="mb-3"></div>
#         </div>
#       </div>
#       <div class="row">
#         <div class="col-lg-7 col-md-6 order-md-12 mb-4 ">
#           <div class="row">
#             <div class="col-md-8 col-6 fontSize8pt text-md-right text-left">
#                   Αξία προ έκπτωσης
#                 </div>
#             <div class="col-md-4 col-6 fontSize8pt" style="text-align:right;">171,82EUR</div>
#           </div>
#           <div class="row">
#             <div class="col-md-8 col-6 fontSize8pt text-md-right text-left" style="text-align:right;">
#                   Έκπτωση
#                 </div>
#             <div class="col-md-4 col-6 fontSize8pt" style="text-align:right;">8,67EUR</div>
#           </div>
#           <div class="row">
#             <div class="col-md-8 col-6 fontSize8pt text-md-right text-left" style="font-weight: bold;text-align:right;">
#                   ΤΕΛΙΚΗ ΑΞΙΑ
#                 </div>
#             <div class="col-md-4 col-6 fontSize8pt" style="text-align:right;font-weight: bold;">
#               <div style="background-color:#f2f2f2;" class="backgrey">163,15EUR</div>
#             </div>
#           </div>
#           <div class="row">
#             <div class="col-md-8 col-6 fontSize6pt text-md-right text-left" style="text-align:right;">
#                   Καθαρή Αξία
#                 </div>
#             <div class="col-md-4 col-6 fontSize6pt" style="text-align:right;">143,42EUR</div>
#           </div>
#           <div class="row">
#             <div class="col-md-8 col-6 fontSize6pt text-md-right text-left" style="text-align:right;">
#                   Φ.Π.Α
#                 </div>
#             <div class="col-md-4 col-6 fontSize6pt" style="text-align:right;">19,73EUR</div>
#           </div>
#         </div>
#         <div class="col-lg-5 col-md-6  order-md-1 mb-4">
#           <div style="background-color:#f2f2f2;padding:2px 5px 0px 5px" class="backgrey">
#             <div class="row BoldBlueHeader fontSize8pt">
#               <div class="col">
#                     ΑΝΑΛΥΣΗ ΦΠΑ
#                   </div>
#             </div>
#             <div class="row pb-1">
#               <div class=" col-3 fontSize8pt" style="text-align:right;font-weight: bold;">
#                     ΦΠΑ%
#                   </div>
#               <div class=" col-6 fontSize8pt" style="text-align:right;font-weight: bold;">
#                     ΚΑΘΑΡΟ ΠΟΣΟ ΑΝΑ ΦΠΑ
#                   </div>
#               <div class=" col-3 fontSize8pt" style="text-align:right;font-weight: bold;">
#                     ΑΞΙΑ ΦΠΑ
#                   </div>
#             </div>
#             <div class="row" style="background-color:white;">
#               <div class=" col-3 fontSize6pt" style="text-align:right;">24%
#                     </div>
#               <div class=" col-6 fontSize6pt" style="text-align:right">9,89EUR</div>
#               <div class=" col-3 fontSize6pt" style="text-align:right">2,37EUR</div>
#             </div>
#             <div class="row" style="background-color:white;">
#               <div class=" col-3 fontSize6pt" style="text-align:right;">13%
#                     </div>
#               <div class=" col-6 fontSize6pt" style="text-align:right">133,53EUR</div>
#               <div class=" col-3 fontSize6pt" style="text-align:right">17,36EUR</div>
#             </div>
#           </div>
#           <div class="mb-3"></div>
#           <div style="background-color:#f2f2f2; padding:2px 5px 0px 5px" class="backgrey">
#             <div class="row BoldBlueHeader fontSize8pt">
#               <div class="col">ΣΤΟΙΧΕΙΑ ΠΛΗΡΩΜΗΣ</div>
#             </div>
#             <div class="row pb-1">
#               <div class=" col-6 fontSize8pt" style="text-align:right;font-weight: bold;">
#                     Τρόπος Πληρωμής
#                   </div>
#               <div class=" col-6 fontSize8pt" style="text-align:right;font-weight: bold;">
#                     Ποσό Πληρωμής
#                   </div>
#             </div>
#             <div class="row">
#               <div class="col-6 fontSize6pt" style="text-align:right;background-color:white;">
#                               POS / e-POS
#                             </div>
#               <div class="col-6 fontSize6pt" style="text-align:right;background-color:white;">163,15EUR</div>
#             </div>
#           </div>
#         </div>
#       </div>
#       <div class="mb-3"></div>
#       <div class="fontSize8pt"><b>ΠΑΡΑΤΗΡΗΣΕΙΣ</b><div class="mb-0"></div>
#       </div>
#       <div class="mb-3"></div>
#       <div class="row fontSize6pt" style="font-family: Segoe UI;">
#         <div class="col-md-6 mb-3">
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">
#                   Πάροχος:
#                 </div>
#             <div class="col-8 fontSize8pt ml-0 pl-0">Entersoft AE</div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">Url πάροχου: </div>
#             <div class="col-8 fontSize8pt ml-0 pl-0"><a href="https://www.entersoft.gr" target="_blank" style="color:black">https://www.entersoft.gr</a></div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">Άδεια καταλληλότητας (ΥΠΑΗΕΣ): </div>
#             <div class="col-8 fontSize8pt ml-0 pl-0">2020_07_102Entersoft_001_Paperless e-Invoicing_V1_31072020</div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">UID: </div>
#             <div class="col-8 fontSize8pt ml-0 pl-0">5D730F9D6115B5726C2BC2B674682E6A99D301B5</div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">M.AR.K: </div>
#             <div class="col-8 fontSize8pt ml-0 pl-0">400012034426045</div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">AuthenticationCode: </div>
#             <div class="col-8 fontSize8pt  ml-0 pl-0">7FA9EA611EF78C1FC3EE742CCF1A7963DAC58BEF</div>
#           </div>
#           <div class="row">
#             <div class="col fontSize8pt mr-0 pr-0">Ημ/νία διαβίβασης: </div>
#             <div class="col-8 fontSize8pt  ml-0 pl-0">20-12-2025 20:21:11</div>
#           </div>
#         </div>
#         <div class="col-md-6" align="right"><span><p></p></span></div>
#       </div>
#       <div class="row printingButton mt-3">
#         <div class="col text-center"><a class="btn btn-primary buttonPrint" title="Εκτύπωση" href="#" onclick="window.print();return false;" id="btnPrint"><i class="fas fa-print"></i> Εκτύπωση
#
#             </a></div>
#       </div>
#     </div><script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script><script src="https://unpkg.com/@popperjs/core@2/dist/umd/popper.min.js" integrity="sha384-I7E8VVD/ismYTF4hNIPjVp/Zjvgyol6VFvRkX/vR+Vc4jQkC+hVqc2pM8ODewa9r" crossorigin="anonymous"></script><script src="https://cdn.jsdelivr.net/npm/tether@2.0.0-beta.5/dist/js/tether.min.js"></script><script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0-alpha.6/js/bootstrap.min.js" integrity="sha384-vBWWzlZJ8ea9aCX4pEW3rVHjgjt7zpkNpZk+02D9phzyeVkE+jo0ieGizqPLForn" crossorigin="anonymous"></script><script>
#           jQuery(document).ready(function ($) {
#
#
#           if (
#           navigator.userAgent.match(/Android/i) ||
#           navigator.userAgent.match(/iPhone/i)
#           ) {
#           $(".printingButton").hide();
#           }
#
#           });
#         </script></body>
# </html>
